# %% [markdown]
# #### Install Library
# To proceed with this exercise, you need to install the following libraries:

# %%
# To proceed with this exercise, you need to install the following libraries:
#!pip install mlxtend

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline

# Import warnings
#warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Reading the Groceries Dataset into DataFrame

# %% [markdown]
# Now let's create a `DataFrame` on this `csv` file.

# %%
# Read dataset from CSV file
df = pd.read_csv('../AllPurchaseData.csv')

# Show information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354345 entries, 0 to 354344
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    354345 non-null  int64
#  1   StockCode    354345 non-null  object
#  2   Description  354345 non-null  object
#  3   Quantity     354345 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 10.8+ MB

# %% [markdown]
# ### 2. Exploratory Data Analysis

# %% [markdown]
# #### Number of unique invoices

# %%
# How many unique invoice numbers?
df["InvoiceNo"].nunique()
# Out:
# 16649

# %% [markdown]
# #### Distribution of Transaction Sizes

# %%
# Show histogram of transaction sizes (i.e. total number of items in each invoice)
txn_sizes = pd.DataFrame(df.groupby('InvoiceNo').sum()['Quantity'])
print("Min: ", txn_sizes.min())
print("Max: ", txn_sizes.max())
# Filter range to 1 - 80995 for min and max quantity of data
txn_sizes['Quantity'].hist(range = (1,80995))
# Out:
# Min:  Quantity    1
# dtype: int64
# Max:  Quantity    80995
# dtype: int64
# <Axes: >

# %%
# Groups transaction data by InvoiceNo and Description to aggregate the total quantity of each item purchased per transaction.
txn = df.groupby(['InvoiceNo', 'Description'])["Quantity"].sum()
print(txn)

# Double-check the number of transactions, is it the same as before?
txn.index.get_level_values('InvoiceNo').nunique()
# Out:
# InvoiceNo  Description
# 536365     CREAM CUPID HEARTS COAT HANGER          8
#            GLASS STAR FROSTED T-LIGHT HOLDER       6
#            KNITTED UNION FLAG HOT WATER BOTTLE     6
#            RED WOOLLY HOTTIE WHITE HEART.          6
#            SET 7 BABUSHKA NESTING BOXES            2
#                                                   ..
# 581585     ZINC WILLIE WINKIE  CANDLE STICK       24
# 581586     DOORMAT RED RETROSPOT                  10
#            LARGE CAKE STAND  HANGING STRAWBERY     8
#            RED RETROSPOT ROUND CAKE TINS          24
#            SET OF 3 HANGING OWLS OLLIE BEAK       24
# Name: Quantity, Length: 344362, dtype: int64
# 16649

# %% [markdown]
# ### 3. Preparing the Data for Market Basket Analysis

# %%
# Transform the data, so that each description becomes a column, and the values in the table represent the quantity
txn_df = txn.unstack(fill_value=0)
txn_df
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# ...                                     ...                             ...
# 581582                                    0                               0
# 581583                                    0                               0
# 581584                                    0                               0
# 581585                                    0                               0
# 581586                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
# ...                         ...                           ...
# 581582                        0                             0
# 581583                        0                             0
# 581584                        0                             0
# 581585                        0                             0
# 581586                        0                             0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                              0                            0
# 536366                              0                            0
# 536367                              0                            0
# 536368                              0                            0
# 536369                              0                            0
# ...                               ...                          ...
# 581582                              0                            0
# 581583                              0                            0
# 581584                              0                            0
# 581585                              0                            0
# 581586                              0                            0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 536365                              0                                 0
# 536366                              0                                 0
# 536367                              0                                 0
# 536368                              0                                 0
# 536369                              0                                 0
# ...                               ...                               ...
# 581582                              0                                 0
# 581583                              0                                 0
# 581584                              0                                 0
# 581585                              0                                 0
# 581586                              0                                 0
#
# Description   SPACEBOY BABY GIFT SET   TOADSTOOL BEDSIDE LIGHT   ...  \
# InvoiceNo                                                        ...
# 536365                             0                          0  ...
# 536366                             0                          0  ...
# 536367                             0                          0  ...
# 536368                             0                          0  ...
# 536369                             0                          0  ...
# ...                              ...                        ...  ...
# 581582                             0                          0  ...
# 581583                             0                          0  ...
# 581584                             0                          0  ...
# 581585                             0                          0  ...
# 581586                             0                          0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
# ...                                ...                        ...
# 581582                               0                          0
# 581583                               0                          0
# 581584                               0                          0
# 581585                               0                          0
# 581586                               0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536369                                      0                               0
# ...                                       ...                             ...
# 581582                                      0                               0
# 581583                                      0                               0
# 581584                                      0                               0
# 581585                                      0                              12
# 581586                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536369                                     0                                0
# ...                                      ...                              ...
# 581582                                     0                                0
# 581583                                     0                                0
# 581584                                     0                                0
# 581585                                     0                                0
# 581586                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                    0                                 0
# 536366                                    0                                 0
# 536367                                    0                                 0
# 536368                                    0                                 0
# 536369                                    0                                 0
# ...                                     ...                               ...
# 581582                                    0                                 0
# 581583                                    0                                 0
# 581584                                    0                                 0
# 581585                                    0                                24
# 581586                                    0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536369                                 0                                 0
# ...                                  ...                               ...
# 581582                                 0                                 0
# 581583                                 0                                 0
# 581584                                 0                                 0
# 581585                                 0                                 0
# 581586                                 0                                 0
#
# [16649 rows x 3844 columns]

# %%
# Binary Encoding (replacing all positives with 1)
txn_df = txn_df.map(lambda x: 0 if x <= 0 else 1)
txn_df
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# ...                                     ...                             ...
# 581582                                    0                               0
# 581583                                    0                               0
# 581584                                    0                               0
# 581585                                    0                               0
# 581586                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
# ...                         ...                           ...
# 581582                        0                             0
# 581583                        0                             0
# 581584                        0                             0
# 581585                        0                             0
# 581586                        0                             0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                              0                            0
# 536366                              0                            0
# 536367                              0                            0
# 536368                              0                            0
# 536369                              0                            0
# ...                               ...                          ...
# 581582                              0                            0
# 581583                              0                            0
# 581584                              0                            0
# 581585                              0                            0
# 581586                              0                            0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 536365                              0                                 0
# 536366                              0                                 0
# 536367                              0                                 0
# 536368                              0                                 0
# 536369                              0                                 0
# ...                               ...                               ...
# 581582                              0                                 0
# 581583                              0                                 0
# 581584                              0                                 0
# 581585                              0                                 0
# 581586                              0                                 0
#
# Description   SPACEBOY BABY GIFT SET   TOADSTOOL BEDSIDE LIGHT   ...  \
# InvoiceNo                                                        ...
# 536365                             0                          0  ...
# 536366                             0                          0  ...
# 536367                             0                          0  ...
# 536368                             0                          0  ...
# 536369                             0                          0  ...
# ...                              ...                        ...  ...
# 581582                             0                          0  ...
# 581583                             0                          0  ...
# 581584                             0                          0  ...
# 581585                             0                          0  ...
# 581586                             0                          0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
# ...                                ...                        ...
# 581582                               0                          0
# 581583                               0                          0
# 581584                               0                          0
# 581585                               0                          0
# 581586                               0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536369                                      0                               0
# ...                                       ...                             ...
# 581582                                      0                               0
# 581583                                      0                               0
# 581584                                      0                               0
# 581585                                      0                               1
# 581586                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536369                                     0                                0
# ...                                      ...                              ...
# 581582                                     0                                0
# 581583                                     0                                0
# 581584                                     0                                0
# 581585                                     0                                0
# 581586                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                    0                                 0
# 536366                                    0                                 0
# 536367                                    0                                 0
# 536368                                    0                                 0
# 536369                                    0                                 0
# ...                                     ...                               ...
# 581582                                    0                                 0
# 581583                                    0                                 0
# 581584                                    0                                 0
# 581585                                    0                                 1
# 581586                                    0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536369                                 0                                 0
# ...                                  ...                               ...
# 581582                                 0                                 0
# 581583                                 0                                 0
# 581584                                 0                                 0
# 581585                                 0                                 0
# 581586                                 0                                 0
#
# [16649 rows x 3844 columns]

# %%
# Keep only transactions with 2 or more items
basket_df = txn_df[txn_df.sum(axis=1) >= 2]
basket_df
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536372                                    0                               0
# ...                                     ...                             ...
# 581582                                    0                               0
# 581583                                    0                               0
# 581584                                    0                               0
# 581585                                    0                               0
# 581586                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536372                        0                             0
# ...                         ...                           ...
# 581582                        0                             0
# 581583                        0                             0
# 581584                        0                             0
# 581585                        0                             0
# 581586                        0                             0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                              0                            0
# 536366                              0                            0
# 536367                              0                            0
# 536368                              0                            0
# 536372                              0                            0
# ...                               ...                          ...
# 581582                              0                            0
# 581583                              0                            0
# 581584                              0                            0
# 581585                              0                            0
# 581586                              0                            0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 536365                              0                                 0
# 536366                              0                                 0
# 536367                              0                                 0
# 536368                              0                                 0
# 536372                              0                                 0
# ...                               ...                               ...
# 581582                              0                                 0
# 581583                              0                                 0
# 581584                              0                                 0
# 581585                              0                                 0
# 581586                              0                                 0
#
# Description   SPACEBOY BABY GIFT SET   TOADSTOOL BEDSIDE LIGHT   ...  \
# InvoiceNo                                                        ...
# 536365                             0                          0  ...
# 536366                             0                          0  ...
# 536367                             0                          0  ...
# 536368                             0                          0  ...
# 536372                             0                          0  ...
# ...                              ...                        ...  ...
# 581582                             0                          0  ...
# 581583                             0                          0  ...
# 581584                             0                          0  ...
# 581585                             0                          0  ...
# 581586                             0                          0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536372                               0                          0
# ...                                ...                        ...
# 581582                               0                          0
# 581583                               0                          0
# 581584                               0                          0
# 581585                               0                          0
# 581586                               0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536372                                      0                               0
# ...                                       ...                             ...
# 581582                                      0                               0
# 581583                                      0                               0
# 581584                                      0                               0
# 581585                                      0                               1
# 581586                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536372                                     0                                0
# ...                                      ...                              ...
# 581582                                     0                                0
# 581583                                     0                                0
# 581584                                     0                                0
# 581585                                     0                                0
# 581586                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                    0                                 0
# 536366                                    0                                 0
# 536367                                    0                                 0
# 536368                                    0                                 0
# 536372                                    0                                 0
# ...                                     ...                               ...
# 581582                                    0                                 0
# 581583                                    0                                 0
# 581584                                    0                                 0
# 581585                                    0                                 1
# 581586                                    0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536372                                 0                                 0
# ...                                  ...                               ...
# 581582                                 0                                 0
# 581583                                 0                                 0
# 581584                                 0                                 0
# 581585                                 0                                 0
# 581586                                 0                                 0
#
# [15376 rows x 3844 columns]

# %% [markdown]
# ### 4. Performing Market Basket Analysis

# %%
# Import for Apriori Algorithm and Association Analysis
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Convert 0's and 1's to boolean values
basket_df = basket_df.astype(bool)

# %%
# Generate the frequent itemsets with support >= 0.02
frequent_itemsets = apriori(basket_df, min_support=0.02, use_colnames=True).sort_values("support",ascending=False)
frequent_itemsets
# Out:
#       support                               itemsets
# 215  0.121358   (WHITE HANGING HEART T-LIGHT HOLDER)
# 93   0.093197              (JUMBO BAG RED RETROSPOT)
# 174  0.090466             (REGENCY CAKESTAND 3 TIER)
# 12   0.084417        (ASSORTED COLOUR BIRD ORNAMENT)
# 144  0.082986                        (PARTY BUNTING)
# ..        ...                                    ...
# 22   0.020226                  (CARD BILLBOARD FONT)
# 211  0.020161      (VINTAGE DOILY TRAVEL SEWING KIT)
# 230  0.020161            (ZINC FOLKART SLEIGH BELLS)
# 104  0.020031  (KNITTED UNION FLAG HOT WATER BOTTLE)
# 138  0.020031       (PANTRY MAGNETIC  SHOPPING LIST)
#
# [277 rows x 2 columns]

# %%
# Create a new variable 'length' which stores the number of items in each itemset
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#       support                               itemsets  length
# 215  0.121358   (WHITE HANGING HEART T-LIGHT HOLDER)       1
# 93   0.093197              (JUMBO BAG RED RETROSPOT)       1
# 174  0.090466             (REGENCY CAKESTAND 3 TIER)       1
# 12   0.084417        (ASSORTED COLOUR BIRD ORNAMENT)       1
# 144  0.082986                        (PARTY BUNTING)       1
# ..        ...                                    ...     ...
# 22   0.020226                  (CARD BILLBOARD FONT)       1
# 211  0.020161      (VINTAGE DOILY TRAVEL SEWING KIT)       1
# 230  0.020161            (ZINC FOLKART SLEIGH BELLS)       1
# 104  0.020031  (KNITTED UNION FLAG HOT WATER BOTTLE)       1
# 138  0.020031       (PANTRY MAGNETIC  SHOPPING LIST)       1
#
# [277 rows x 3 columns]

# %%
# Keep only itemsets with at least 2 items
frequent_itemsets[frequent_itemsets['length'] >= 2]
# Out:
#       support                                           itemsets  length
# 243  0.032908  (JUMBO BAG RED RETROSPOT, JUMBO BAG PINK POLKA...       2
# 252  0.031478  (LUNCH BAG RED RETROSPOT, LUNCH BAG  BLACK SKU...       2
# 235  0.030957  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , LAY'S...       2
# 264  0.030632  (LUNCH BAG PINK POLKADOT, LUNCH BAG RED RETROS...       2
# 239  0.029787  (GARDENERS KNEELING PAD KEEP CALM , GARDENERS ...       2
# 275  0.029787  (WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRA...       2
# 232  0.029527  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...       2
# 251  0.028746  (LUNCH BAG PINK POLKADOT, LUNCH BAG  BLACK SKU...       2
# 272  0.028421  (PAPER CHAIN KIT 50'S CHRISTMAS , PAPER CHAIN ...       2
# 274  0.027836  (RED HANGING HEART T-LIGHT HOLDER, WHITE HANGI...       2
# 259  0.026860     (LUNCH BAG RED RETROSPOT, LUNCH BAG CARS BLUE)       2
# 268  0.026665  (LUNCH BAG RED RETROSPOT, LUNCH BAG SUKI DESIGN )       2
# 267  0.026665  (LUNCH BAG RED RETROSPOT, LUNCH BAG SPACEBOY D...       2
# 247  0.026535  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI)       2
# 237  0.026275  (LAY'S JAPANESE SEAWEED POTATO CHIPS, COOKIES ...       2
# 250  0.026145     (LUNCH BAG  BLACK SKULL., LUNCH BAG CARS BLUE)       2
# 240  0.025884     (HEART OF WICKER LARGE, HEART OF WICKER SMALL)       2
# 258  0.025754     (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE)       2
# 244  0.025689    (JUMBO BAG STRAWBERRY, JUMBO BAG RED RETROSPOT)       2
# 254  0.025559  (LUNCH BAG  BLACK SKULL., LUNCH BAG SUKI DESIGN )       2
# 253  0.025299  (LUNCH BAG  BLACK SKULL., LUNCH BAG SPACEBOY D...       2
# 234  0.024909  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , COOKI...       2
# 248  0.024519  (LUNCH BAG RED RETROSPOT, JUMBO BAG RED RETROS...       2
# 246  0.024259  (JUMBO BAG RED RETROSPOT, JUMBO SHOPPER VINTAG...       2
# 269  0.023673      (LUNCH BAG RED RETROSPOT, LUNCH BAG WOODLAND)       2
# 260  0.023608  (LUNCH BAG SPACEBOY DESIGN , LUNCH BAG CARS BLUE)       2
# 261  0.023608      (LUNCH BAG SUKI DESIGN , LUNCH BAG CARS BLUE)       2
# 273  0.023348                    (SPOTTY BUNTING, PARTY BUNTING)       2
# 236  0.022893  (REGENCY CAKESTAND 3 TIER, CHESTERS FLAMIN' HO...       2
# 270  0.022633  (LUNCH BAG SPACEBOY DESIGN , LUNCH BAG SUKI DE...       2
# 241  0.022568  (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG RED...       2
# 271  0.022503   (LUNCH BAG SPACEBOY DESIGN , LUNCH BAG WOODLAND)       2
# 276  0.022177  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , LAY'S...       3
# 265  0.021722  (LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY D...       2
# 266  0.021657  (LUNCH BAG PINK POLKADOT, LUNCH BAG SUKI DESIGN )       2
# 256  0.021657  (LUNCH BAG RED RETROSPOT, LUNCH BAG APPLE DESIGN)       2
# 257  0.021397   (LUNCH BAG SUKI DESIGN , LUNCH BAG APPLE DESIGN)       2
# 255  0.021072      (LUNCH BAG  BLACK SKULL., LUNCH BAG WOODLAND)       2
# 245  0.021072  (JUMBO BAG RED RETROSPOT, JUMBO BAG VINTAGE LEAF)       2
# 249  0.020877  (REGENCY CAKESTAND 3 TIER, LAY'S JAPANESE SEAW...       2
# 233  0.020812  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...       2
# 262  0.020747          (LUNCH BAG WOODLAND, LUNCH BAG CARS BLUE)       2
# 263  0.020356  (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG SPACEB...       2
# 238  0.020356        (DOLLY GIRL LUNCH BOX, SPACEBOY LUNCH BOX )       2
# 242  0.020356        (JUMBO BAG RED RETROSPOT, JUMBO BAG APPLES)       2

# %%
# Count how many itemsets have at least 2 items
frequent_itemsets[frequent_itemsets['length'] >= 2].count()
# Out:
# support     45
# itemsets    45
# length      45
# dtype: int64

# %%
# Show association rules with lift >= 10
assoc_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=10).sort_values("lift",ascending=False)
assoc_rules.head(10)
# Out:
#                                           antecedents  \
# 19                (COOKIES AND CREAM DREAM CAKE 200g)
# 14  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , LAY'S...
# 15  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , COOKI...
# 18              (LAY'S JAPANESE SEAWEED POTATO CHIPS)
# 11                (COOKIES AND CREAM DREAM CAKE 200g)
# 10              (LAY'S JAPANESE SEAWEED POTATO CHIPS)
# 25                              (SPACEBOY LUNCH BOX )
# 24                             (DOLLY GIRL LUNCH BOX)
# 16  (LAY'S JAPANESE SEAWEED POTATO CHIPS, COOKIES ...
# 17           (CHESTERS FLAMIN' HOT FRIES CHIPS 270g )
#
#                                           consequents  antecedent support  \
# 19  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , LAY'S...            0.031803
# 14                (COOKIES AND CREAM DREAM CAKE 200g)            0.030957
# 15              (LAY'S JAPANESE SEAWEED POTATO CHIPS)            0.024909
# 18  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , COOKI...            0.039802
# 11              (LAY'S JAPANESE SEAWEED POTATO CHIPS)            0.031803
# 10                (COOKIES AND CREAM DREAM CAKE 200g)            0.039802
# 25                             (DOLLY GIRL LUNCH BOX)            0.032908
# 24                              (SPACEBOY LUNCH BOX )            0.030372
# 16           (CHESTERS FLAMIN' HOT FRIES CHIPS 270g )            0.026275
# 17  (LAY'S JAPANESE SEAWEED POTATO CHIPS, COOKIES ...            0.043900
#
#     consequent support   support  confidence       lift  representativity  \
# 19            0.030957  0.022177    0.697342  22.525889               1.0
# 14            0.031803  0.022177    0.716387  22.525889               1.0
# 15            0.039802  0.022177    0.890339  22.369051               1.0
# 18            0.024909  0.022177    0.557190  22.369051               1.0
# 11            0.039802  0.026275    0.826176  20.756994               1.0
# 10            0.031803  0.026275    0.660131  20.756994               1.0
# 25            0.030372  0.020356    0.618577  20.366683               1.0
# 24            0.032908  0.020356    0.670236  20.366683               1.0
# 16            0.043900  0.022177    0.844059  19.227048               1.0
# 17            0.026275  0.022177    0.505185  19.227048               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 19  0.021193    3.201769       0.986996  0.546474   0.687673    0.706864
# 14  0.021193    3.413792       0.986135  0.546474   0.707071    0.706864
# 15  0.021186    8.756089       0.979699  0.521407   0.885794    0.723764
# 18  0.021186    2.202051       0.994894  0.521407   0.545878    0.723764
# 11  0.025009    5.523961       0.983088  0.579627   0.818970    0.743153
# 10  0.025009    2.848734       0.991279  0.579627   0.648967    0.743153
# 25  0.019357    2.542133       0.983258  0.474242   0.606630    0.644406
# 24  0.019357    2.932674       0.980686  0.474242   0.659014    0.644406
# 16  0.021024    6.131184       0.973570  0.462060   0.836899    0.674622
# 17  0.021024    1.967858       0.991517  0.462060   0.491833    0.674622

# %%
# Show column names
assoc_rules.columns
# Out:
# Index(['antecedents', 'consequents', 'antecedent support',
#        'consequent support', 'support', 'confidence', 'lift',
#        'representativity', 'leverage', 'conviction', 'zhangs_metric',
#        'jaccard', 'certainty', 'kulczynski'],
#       dtype='object')

# %%
# Keep only the columns that we learned in the Analytics Foundation
assoc_rules2 = assoc_rules[['antecedents', 'consequents', 'support', 'confidence', 'consequent support', 'lift']].rename(columns={
    'antecedents': 'LHS',
    'consequents': 'RHS',
    'support': 'Support',
    'confidence': 'Confidence',
    'consequent support': 'Expected Confidence',
    'lift': 'Lift',
})
assoc_rules2
# Out:
#                                                   LHS  \
# 19                (COOKIES AND CREAM DREAM CAKE 200g)
# 14  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , LAY'S...
# 15  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , COOKI...
# 18              (LAY'S JAPANESE SEAWEED POTATO CHIPS)
# 11                (COOKIES AND CREAM DREAM CAKE 200g)
# 10              (LAY'S JAPANESE SEAWEED POTATO CHIPS)
# 25                              (SPACEBOY LUNCH BOX )
# 24                             (DOLLY GIRL LUNCH BOX)
# 16  (LAY'S JAPANESE SEAWEED POTATO CHIPS, COOKIES ...
# 17           (CHESTERS FLAMIN' HOT FRIES CHIPS 270g )
# 12           (CHESTERS FLAMIN' HOT FRIES CHIPS 270g )
# 13                (COOKIES AND CREAM DREAM CAKE 200g)
# 1               (LAY'S JAPANESE SEAWEED POTATO CHIPS)
# 0            (CHESTERS FLAMIN' HOT FRIES CHIPS 270g )
# 3                (GARDENERS KNEELING PAD CUP OF TEA )
# 2                 (GARDENERS KNEELING PAD KEEP CALM )
# 7                        (ALARM CLOCK BAKELIKE GREEN)
# 6                         (ALARM CLOCK BAKELIKE RED )
# 20                        (ALARM CLOCK BAKELIKE RED )
# 21                        (ALARM CLOCK BAKELIKE PINK)
# 9                 (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 8                   (PAPER CHAIN KIT 50'S CHRISTMAS )
# 22                      (LUNCH BAG DOLLY GIRL DESIGN)
# 23                       (LUNCH BAG SPACEBOY DESIGN )
# 5                       (WOODEN FRAME ANTIQUE WHITE )
# 4                 (WOODEN PICTURE FRAME WHITE FINISH)
#
#                                                   RHS   Support  Confidence  \
# 19  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , LAY'S...  0.022177    0.697342
# 14                (COOKIES AND CREAM DREAM CAKE 200g)  0.022177    0.716387
# 15              (LAY'S JAPANESE SEAWEED POTATO CHIPS)  0.022177    0.890339
# 18  (CHESTERS FLAMIN' HOT FRIES CHIPS 270g , COOKI...  0.022177    0.557190
# 11              (LAY'S JAPANESE SEAWEED POTATO CHIPS)  0.026275    0.826176
# 10                (COOKIES AND CREAM DREAM CAKE 200g)  0.026275    0.660131
# 25                             (DOLLY GIRL LUNCH BOX)  0.020356    0.618577
# 24                              (SPACEBOY LUNCH BOX )  0.020356    0.670236
# 16           (CHESTERS FLAMIN' HOT FRIES CHIPS 270g )  0.022177    0.844059
# 17  (LAY'S JAPANESE SEAWEED POTATO CHIPS, COOKIES ...  0.022177    0.505185
# 12                (COOKIES AND CREAM DREAM CAKE 200g)  0.024909    0.567407
# 13           (CHESTERS FLAMIN' HOT FRIES CHIPS 270g )  0.024909    0.783231
# 1            (CHESTERS FLAMIN' HOT FRIES CHIPS 270g )  0.030957    0.777778
# 0               (LAY'S JAPANESE SEAWEED POTATO CHIPS)  0.030957    0.705185
# 3                 (GARDENERS KNEELING PAD KEEP CALM )  0.029787    0.731629
# 2                (GARDENERS KNEELING PAD CUP OF TEA )  0.029787    0.618084
# 7                         (ALARM CLOCK BAKELIKE RED )  0.029527    0.662774
# 6                        (ALARM CLOCK BAKELIKE GREEN)  0.029527    0.598945
# 20                        (ALARM CLOCK BAKELIKE PINK)  0.020812    0.422164
# 21                        (ALARM CLOCK BAKELIKE RED )  0.020812    0.651731
# 9                   (PAPER CHAIN KIT 50'S CHRISTMAS )  0.028421    0.649331
# 8                 (PAPER CHAIN KIT VINTAGE CHRISTMAS)  0.028421    0.465885
# 22                       (LUNCH BAG SPACEBOY DESIGN )  0.020356    0.604247
# 23                      (LUNCH BAG DOLLY GIRL DESIGN)  0.020356    0.358534
# 5                 (WOODEN PICTURE FRAME WHITE FINISH)  0.029787    0.585678
# 4                       (WOODEN FRAME ANTIQUE WHITE )  0.029787    0.537559
#
#     Expected Confidence       Lift
# 19             0.030957  22.525889
# 14             0.031803  22.525889
# 15             0.039802  22.369051
# 18             0.024909  22.369051
# 11             0.039802  20.756994
# 10             0.031803  20.756994
# 25             0.030372  20.366683
# 24             0.032908  20.366683
# 16             0.043900  19.227048
# 17             0.026275  19.227048
# 12             0.031803  17.841424
# 13             0.043900  17.841424
# 1              0.043900  17.717202
# 0              0.039802  17.717202
# 3              0.048192  15.181557
# 2              0.040713  15.181557
# 7              0.049298  13.444339
# 6              0.044550  13.444339
# 20             0.031933  13.220341
# 21             0.049298  13.220341
# 9              0.061004  10.644050
# 8              0.043770  10.644050
# 22             0.056777  10.642501
# 23             0.033689  10.642501
# 5              0.055411  10.569696
# 4              0.050858  10.569696

# %% [markdown]
# #### Visualising the Association Rules (using Lift)

# %%
# Pivot table for heatmap, where the rows are "LHS" of rules, columns are "RHS" of rules,
# and values (colors) represent lift values
rules_pivot = assoc_rules2.pivot(index="LHS", columns="RHS", values="Lift").fillna(0)

# Set size of figure
plt.figure(figsize=(15, 15))

# Generate heatmap
ax = sns.heatmap(rules_pivot, annot=True, cmap="coolwarm", fmt=".2f")

# Rotate x-axis labels at 45 degrees, align right
plt.xticks(rotation=45, ha="right")  

# Set title and show heatmap
plt.title("Heatmap of Association Rules (Lift Values)")
plt.show()
